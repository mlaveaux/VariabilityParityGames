# %%
import pandas as pd
import matplotlib.pyplot as plt
df  = pd.read_csv("/home/sjef/assist.csv")
# df = df.groupby('n').mean().reset_index()
df.plot(kind='scatter',x='n',y='t',s=1) # scatter plot
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-15c51ad8fc5b> in <module>()
#       3 df  = pd.read_csv("/home/sjef/assist.csv")
#       4 # df = df.groupby('n').mean().reset_index()
# ----> 5 df.plot(kind='scatter',x='n',y='t') # scatter plot
#
# /home/sjef/anaconda2/lib/python2.7/site-packages/pandas/plotting/_core.pyc in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2939                           fontsize=fontsize, colormap=colormap, table=table,
#    2940                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2941                           sort_columns=sort_columns, **kwds)
#    2942     __call__.__doc__ = plot_frame.__doc__
#    2943
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
df  = pd.read_csv("/home/sjef/assistminepump2.csv")
df = df.groupby('n').mean().reset_index()
df.plot(kind='scatter',x='n',y='t',s=1) # scatter plot
